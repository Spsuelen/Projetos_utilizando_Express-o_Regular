# %%
import pandas as pd
import re

# %%
historias_usuario = [
    "Como usuário, desejo iniciar minha sessão clicando no ícone da aplicação e usando o botão de início para começar uma nova atividade.",
    "Como usuário, quero configurar minhas preferências selecionando um item específico no seletor.",
    "Como usuário, pretendo obter detalhes escolhendo a primeira opção disponível na lista.",
    "Como usuário, quero prosseguir com minha escolha selecionando a segunda opção na lista.",
    "Como usuário, quero verificar as funcionalidades explorando a terceira opção na lista e acessar o botão de mais opções para ajustes adicionais.",
    "Como usuário, quero visualizar detalhes específicos do treino para decisões informadas.",
    "Como usuário, desejo editar as configurações clicando no botão de edição e importar da nuvem para facilitar a gestão dos meus dados.",
    "Como usuário, pretendo salvar alterações após editar as configurações do meu perfil e importar de outro local para manter meus registros atualizados.",
    "Como usuário, pretendo resetar as configurações para restaurar o estado inicial e acessar a página de configurações de som para ajustar as preferências sonoras.",
    "Como usuário, quero remover um item da lista de exercícios quando não for mais necessário e configurar lembretes para manter minha prática consistente.",
    "Como usuário, pretendo duplicar um exercício existente na minha lista de treinos para criar uma versão modificada com ajustes personalizados e ativar o modo de depuração para fins de desenvolvimento.",
    "Como usuário, quero acessar uma opção específica para personalizar minha experiência.",
    "Como usuário, desejo publicar minhas configurações atualizadas para compartilhar com outros usuários.",
    "Como usuário, pretendo exportar meus dados de treino para um formato compatível com outros aplicativos.",
    "Como usuário, quero acessar a página de menu de configuração para personalizar as preferências e escolher entre opção 1 e opção 2 para decisões específicas."
]

# %%
regex_icone = r"clicando no ícone da aplicação\s(.*?)\se usando o botão de início"
regex_botao_start = r"usando o botão de início\s(.*?)\."
regex_seletor = r"selecionando um item específico no seletor\s(.*?)\."
regex_primeira_opcao_treino = r"escolhendo a primeira opção disponível na lista\s(.*?)\."
regex_segunda_opcao_treino = r"selecionando a segunda opção na lista\s(.*?)\."
regex_terceira_opcao_treino = r"explorando a terceira opção na lista\s(.*?)\se acessar o botão de mais opções"
regex_opcao_treino_homem = r"opção correspondente para homens\s(.*?)\."
regex_opcao_treino_mulher = r"opção apropriada para mulheres\s(.*?)\."
regex_vizualizacao_treino = r"detalhes específicos do treino\s(.*?)\."
regex_primeira_vizualizacao = r"importar da nuvem\s(.*?)\."
regex_segunda_vizualizacao = r"importar de outro local\s(.*?)\spara manter meus registros atualizados"
regex_terceira_vizualizacao = r"restaurar o estado inicial\s(.*?)\se acessar a página de configurações"
regex_editar = r"clicando no botão de edição\s(.*?)\se importar da nuvem"
regex_salvar = r"após editar as configurações do meu perfil\s(.*?)\se importar de outro local"
regex_resetar = r"para restaurar o estado inicial\s(.*?)\se acessar a página de configurações"
regex_opcao = r"escolher entre opção 1\s(.*?)\se opção 2 para decisões específicas"
regex_deletar = r"remover um item da lista de exercícios\s(.*?)\."
regex_duplicar = r"duplicar um exercício existente na minha lista de treinos\s(.*?)\se ativar o modo de depuração"
regex_publicar = r"publicar minhas configurações atualizadas\s(.*?)\."
regex_exportar = r"exportar meus dados de treino\s(.*?)\spara um formato compatível"
regex_botao_mais_opcoes = r"acessar o botão de mais opções\s(.*?)\spara ajustes adicionais"
regex_adicionar_novo_treino = r"importar da nuvem\s(.*?)\spara facilitar a gestão dos meus dados"
regex_importar_nuvem = r"importar da nuvem\s(.*?)\."
regex_importar_outro_local = r"importar de outro local\s(.*?)\spara manter meus registros atualizados"
regex_botao_navegacao = r"navegando para a página de treino\s(.*?)\."
regex_home = r"acessar a página de menu inicial\s(.*?)\."
regex_treino = r"acessar a página de treino\s(.*?)\."
regex_configuracao = r"acessar a página de configuração\s(.*?)\."
regex_ajuda = r"acessar a página de ajuda\s(.*?)\."
regex_sobre = r"acessar a página Sobre\s(.*?)\."
regex_pagina_menu_inicial = r"acessar a página de menu inicial\s(.*?)\."
regex_pagina_menu_treino = r"navegando para a página de treino\s(.*?)\."
regex_pagina_menu_configuracao = r"navegando para a página de configuração\s(.*?)\."
regex_tema_escuro = r"ativar o tema escuro\s(.*?)\."
regex_ativar_depuracao = r"ativar o modo de depuração\s(.*?)\."
regex_lembrete = r"configurar lembretes\s(.*?)\."
regex_som = r"acessar a página de configuração de som\s(.*?)\."
regex_pagina_ajuda = r"acessar a página de ajuda\s(.*?)\."
regex_botao_permissao = r"botão de permissão\s(.*?)\."
regex_pagina_som = r"acessar a página de configuração de som\s(.*?)\."
regex_botao_aceite = r"botão de aceite\s(.*?)\."
regex_opcao_1 = r"escolher entre opção 1\s(.*?)\."
regex_opcao_2 = r"escolher entre opção 2\s(.*?)\."


mapeamento_elementos = {
    "icone": "accessibility id openWorkout",
    "botao_start": "id com.health.openworkout:id/startView",
    "seletor": "id com.health.openworkout:id/trainingNameView",
    "primeira_opcao_treino": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.ListView/android.widget.TextView[1]",
    "segunda_opcao_treino": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.ListView/android.widget.TextView[2]",
    "terceira_opcao_treino": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.ListView/android.widget.TextView[3]",
    "opcao_treino_homem": "id com.health.openworkout:id/radioMale",
    "opcao_treino_mulher": "id com.health.openworkout:id/radioFemale",
    "vizualizacao_treino": "id com.health.openworkout:id/detailTrainingView",
    "primeira_vizualizacao": "xpath /hierarchy/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/androidx.drawerlayout.widget.DrawerLayout/android.view.ViewGroup/android.view.ViewGroup/android.widget.FrameLayout/android.view.ViewGroup/androidx.recyclerview.widget.RecyclerView/android.widget.LinearLayout[1]/android.widget.FrameLayout/android.view.ViewGroup/android.widget.ImageView[3]",
    "segunda_vizualizacao": "xpath /hierarchy/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/androidx.drawerlayout.widget.DrawerLayout/android.view.ViewGroup/android.view.ViewGroup/android.widget.FrameLayout/android.view.ViewGroup/androidx.recyclerview.widget.RecyclerView/android.widget.LinearLayout[2]/android.widget.FrameLayout/android.view.ViewGroup/android.widget.ImageView[3]",
    "terceira_vizualizacao": "xpath /hierarchy/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/androidx.drawerlayout.widget.DrawerLayout/android.view.ViewGroup/android.view.ViewGroup/android.widget.FrameLayout/android.view.ViewGroup/androidx.recyclerview.widget.RecyclerView/android.widget.LinearLayout[3]/android.widget.FrameLayout/android.view.ViewGroup/android.widget.ImageView[3]",
    "editar": "accessibility id Edit",
    "salvar": "accessibility id Save",
    "resetar": "accessibility id Reset",
    "opcao": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.ListView/android.widget.TextView[4]",
    "deletar": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.ListView/android.widget.TextView[5]",
    "duplicar": "id com.health.openworkout:id/menuAdd",
    "publicar": "id com.health.openworkout:id/menuShare",
    "exportar": "id com.health.openworkout:id/menuExport",
    "botao_mais_opcoes": "id com.health.openworkout:id/buttonMoreOptions",
    "adicionar_novo_treino": "accessibility id addNewTraining",
    "importar_nuvem": "id com.health.openworkout:id/menuImportFromCloud",
    "importar_outro_local": "id com.health.openworkout:id/menuImportFromOther",
    "botao_navegacao": "id com.health.openworkout:id/bottomNavigationView",
    "home": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[1]",
    "treino": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[2]",
    "configuracao": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[3]",
    "ajuda": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[4]",
    "sobre": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[5]",
    "pagina_menu_inicial": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[6]",
    "pagina_menu_treino": "id com.health.openworkout:id/trainingsFragment",
    "pagina_menu_configuracao": "id com.health.openworkout:id/configurationsFragment",
    "tema_escuro": "id com.health.openworkout:id/darkMode",
    "ativar_depuracao": "id com.health.openworkout:id/debugMode",
    "lembrete": "id com.health.openworkout:id/reminderSettings",
    "som": "id com.health.openworkout:id/soundSettings",
    "pagina_ajuda": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[4]",
    "botao_permissao": "id com.health.openworkout:id/permissionButton",
    "pagina_som": "id com.health.openworkout:id/soundSettings",
    "botao_aceite": "id com.health.openworkout:id/acceptButton",
    "opcao_1": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[1]",
    "opcao_2": "xpath /hierarchy/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.LinearLayout/android.widget.FrameLayout/android.view.ViewGroup/android.widget.FrameLayout/android.widget.FrameLayout/android.widget.TextView[2]"
}

# %%
dataframes = []

for historia in historias_usuario:
    for campo, id_aplicacao in mapeamento_elementos.items():
        match = None
        valor = None
        action = "type"
        tipo = "edittext"

        if "icone" in campo:
            match = re.search(regex_icone, historia, re.IGNORECASE)
        elif "botao_start" in campo:
            match = re.search(regex_botao_start, historia, re.IGNORECASE)
        elif "seletor" in campo:
            match = re.search(regex_seletor, historia, re.IGNORECASE)
        elif "primeira_opcao_treino" in campo:
            match = re.search(regex_primeira_opcao_treino, historia, re.IGNORECASE)
        elif "segunda_opcao_treino" in campo:
            match = re.search(regex_segunda_opcao_treino, historia, re.IGNORECASE)
        elif "terceira_opcao_treino" in campo:
            match = re.search(regex_terceira_opcao_treino, historia, re.IGNORECASE)
        elif "opcao_treino_homem" in campo:
            match = re.search(regex_opcao_treino_homem, historia, re.IGNORECASE)
        elif "opcao_treino_mulher" in campo:
            match = re.search(regex_opcao_treino_mulher, historia, re.IGNORECASE)
        elif "vizualizacao_treino" in campo:
            match = re.search(regex_vizualizacao_treino, historia, re.IGNORECASE)
        elif "primeira_vizualizacao" in campo:
            match = re.search(regex_primeira_vizualizacao, historia, re.IGNORECASE)
        elif "segunda_vizualizacao" in campo:
            match = re.search(regex_segunda_vizualizacao, historia, re.IGNORECASE)
        elif "terceira_vizualizacao" in campo:
            match = re.search(regex_terceira_vizualizacao, historia, re.IGNORECASE)
        elif "editar" in campo:
            match = re.search(regex_editar, historia, re.IGNORECASE)
        elif "salvar" in campo:
            match = re.search(regex_salvar, historia, re.IGNORECASE)
        elif "resetar" in campo:
            match = re.search(regex_resetar, historia, re.IGNORECASE)
        elif "opcao" in campo:
            match = re.search(regex_opcao, historia, re.IGNORECASE)
        elif "deletar" in campo:
            match = re.search(regex_deletar, historia, re.IGNORECASE)
        elif "duplicar" in campo:
            match = re.search(regex_duplicar, historia, re.IGNORECASE)
        elif "publicar" in campo:
            match = re.search(regex_publicar, historia, re.IGNORECASE)
        elif "exportar" in campo:
            match = re.search(regex_exportar, historia, re.IGNORECASE)
        elif "botao_mais_opcoes" in campo:
            match = re.search(regex_botao_mais_opcoes, historia, re.IGNORECASE)
        elif "adicionar_novo_treino" in campo:
            match = re.search(regex_adicionar_novo_treino, historia, re.IGNORECASE)
        elif "importar_nuvem" in campo:
            match = re.search(regex_importar_nuvem, historia, re.IGNORECASE)
        elif "importar_outro_local" in campo:
            match = re.search(regex_importar_outro_local, historia, re.IGNORECASE)
        elif "botao_navegacao" in campo:
            match = re.search(regex_botao_navegacao, historia, re.IGNORECASE)
        elif "home" in campo:
            match = re.search(regex_home, historia, re.IGNORECASE)
        elif "treino" in campo:
            match = re.search(regex_treino, historia, re.IGNORECASE)
        elif "configuracao" in campo:
            match = re.search(regex_configuracao, historia, re.IGNORECASE)
        elif "ajuda" in campo:
            match = re.search(regex_ajuda, historia, re.IGNORECASE)
        elif "sobre" in campo:
            match = re.search(regex_sobre, historia, re.IGNORECASE)
        elif "pagina_menu_inicial" in campo:
            match = re.search(regex_pagina_menu_inicial, historia, re.IGNORECASE)
        elif "pagina_menu_treino" in campo:
            match = re.search(regex_pagina_menu_treino, historia, re.IGNORECASE)
        elif "pagina_menu_configuracao" in campo:
            match = re.search(regex_pagina_menu_configuracao, historia, re.IGNORECASE)
        elif "tema_escuro" in campo:
            match = re.search(regex_tema_escuro, historia, re.IGNORECASE)
        elif "ativar_depuracao" in campo:
            match = re.search(regex_ativar_depuracao, historia, re.IGNORECASE)
        elif "lembrete" in campo:
            match = re.search(regex_lembrete, historia, re.IGNORECASE)
        elif "som" in campo:
            match = re.search(regex_som, historia, re.IGNORECASE)
        elif "pagina_ajuda" in campo:
            match = re.search(regex_pagina_ajuda, historia, re.IGNORECASE)
        elif "botao_permissao" in campo:
            match = re.search(regex_botao_permissao, historia, re.IGNORECASE)
        elif "pagina_som" in campo:
            match = re.search(regex_pagina_som, historia, re.IGNORECASE)
        elif "botao_aceite" in campo:
            match = re.search(regex_botao_aceite, historia, re.IGNORECASE)
        elif "opcao_1" in campo:
            match = re.search(regex_opcao_1, historia, re.IGNORECASE)
        elif "opcao_2" in campo:
            match = re.search(regex_opcao_2, historia, re.IGNORECASE)

        if match:
            valor = match.group(1).strip("'") if match.lastindex is not None and match.lastindex >= 1 else match.group().strip()

            dataframes.append(pd.DataFrame({
                "Activity": ["App activity"],
                "Field": [campo],
                "ID": [id_aplicacao],
                "Action": [action],
                "Type": [tipo],
                "Size_Start": [1],
                "Size_End": [len(valor)],
                "Value": [valor]
            }))
if dataframes:
    df_final = pd.concat(dataframes, ignore_index=True)
    df_final.to_csv("OpenW.csv", index=False)
else:
    pass

# %%
from google.colab import files
files.download("OpenW.csv")

# %%
df_final
# Out:
#        Activity                  Field  \
# 0  App activity            botao_start
# 1  App activity    vizualizacao_treino
# 2  App activity  primeira_vizualizacao
# 3  App activity         importar_nuvem
# 4  App activity                deletar
# 5  App activity               lembrete
# 6  App activity               duplicar
# 7  App activity       ativar_depuracao
# 8  App activity               publicar
#
#                                                   ID Action      Type  \
# 0             id com.health.openworkout:id/startView   type  edittext
# 1    id com.health.openworkout:id/detailTrainingView   type  edittext
# 2  xpath /hierarchy/android.widget.FrameLayout/an...   type  edittext
# 3   id com.health.openworkout:id/menuImportFromCloud   type  edittext
# 4  xpath /hierarchy/android.widget.FrameLayout/an...   type  edittext
# 5      id com.health.openworkout:id/reminderSettings   type  edittext
# 6               id com.health.openworkout:id/menuAdd   type  edittext
# ...
